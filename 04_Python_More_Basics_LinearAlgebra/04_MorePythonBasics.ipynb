# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('mobile_cleaned-1549119762886.csv')

# %%
df.head()
# Out:
#    sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0         0        12        55   155.0            250                  1.3
# 1         0         1        55   132.0            300                  1.3
# 2         0         9        55   142.0            329                  1.5
# 3         0         8        55   152.0            385                  1.3
# 4         1         1        55   234.0            385                  1.3
#
#    thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 0       10.5           5                     2.00           0  ...
# 1       10.6           5                     0.30           1  ...
# 2        8.5           5                     2.00           3  ...
# 3        8.0           5                     2.00           3  ...
# 4        7.9           5                     1.92           3  ...
#
#    micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# 0              4                     2                 3         67.8
# 1              4                     4                 6         64.0
# 2              4                     9                 6         72.0
# 3              4                     1                 3         75.1
# 4              4                     1                 6         91.0
#
#    expandable_memory  version  usb_type  battery_capacity  processor_rank  \
# 0               64.0        5         3              2000             125
# 1               32.0        5         3              2000             165
# 2               32.0        6         3              2500             164
# 3               32.0        6         3              3000             165
# 4               32.0        6         3              3000             165
#
#    is_liked
# 0         1
# 1         1
# 2         0
# 3         1
# 4         0
#
# [5 rows x 40 columns]

# %%
df.tail()
# Out:
#      sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 104         3        10        14   192.0            540                  1.8
# 105         0         5         3   157.0            400                  2.3
# 106         3        10         6   192.0            384                  1.8
# 107         3        10        12   129.0            250                  1.4
# 108         2         8         3   158.0            400                  2.2
#
#      thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 104        9.4           2                      2.0           2  ...
# 105        7.7           5                      5.0           3  ...
# 106        7.3           2                      5.0           3  ...
# 107        6.9           2                      1.2           3  ...
# 108        7.4           6                      8.0           3  ...
#
#      micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# 104              4                    29                 6         77.2
# 105              6                    27                 1         72.6
# 106              1                    16                 6         77.9
# 107              1                    13                 6         67.0
# 108              5                    16                 6         74.7
#
#      expandable_memory  version  usb_type  battery_capacity  processor_rank  \
# 104              256.0        6         3              3410               8
# 105              200.0        9         3              3600             101
# 106                0.0       14        13              2750               1
# 107                0.0       12        13              1810               7
# 108                0.0       10        12              3000               2
#
#      is_liked
# 104         1
# 105         1
# 106         1
# 107         1
# 108         0
#
# [5 rows x 40 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
dir(df) # all the functions available
# Out:
# ['FM',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_accum_func',
#  '_add_numeric_operations',
#  '_agg_by_level',
#  '_agg_examples_doc',
#  '_agg_summary_and_see_also_doc',
#  '_align_frame',
#  '_align_series',
#  '_arith_method',
#  '_as_manager',
#  '_attrs',
#  '_box_col_values',
#  '_can_fast_transpose',
#  '_check_inplace_and_allows_duplicate_labels',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_cmp_method',
#  '_combine_frame',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_from_arguments',
#  '_construct_result',
#  '_constructor',
#  '_constructor_sliced',
#  '_convert',
#  '_count_level',
#  '_data',
#  '_dir_additions',
#  '_dir_deletions',
#  '_dispatch_frame_op',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_ensure_valid_index',
#  '_find_valid_index',
#  '_flags',
#  '_from_arrays',
#  '_from_mgr',
#  '_get_agg_axis',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cleaned_column_resolvers',
#  '_get_column_array',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_getitem_bool_array',
#  '_getitem_multilevel',
#  '_gotitem',
#  '_hidden_attrs',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_info_repr',
#  '_init_mgr',
#  '_inplace_method',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_copy',
#  '_is_homogeneous_type',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_view',
#  '_iset_item',
#  '_iset_item_mgr',
#  '_iset_not_inplace',
#  '_item_cache',
#  '_iter_column_arrays',
#  '_ixs',
#  '_join_compat',
#  '_logical_func',
#  '_logical_method',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_mgr',
#  '_min_count_stat_function',
#  '_needs_reindex_multi',
#  '_protect_consolidate',
#  '_reduce',
#  '_reindex_axes',
#  '_reindex_columns',
#  '_reindex_index',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_replace_columnwise',
#  '_repr_data_resource_',
#  '_repr_fits_horizontal_',
#  '_repr_fits_vertical_',
#  '_repr_html_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_sanitize_column',
#  '_series',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_axis_nocheck',
#  '_set_is_copy',
#  '_set_item',
#  '_set_item_frame_value',
#  '_set_item_mgr',
#  '_set_value',
#  '_setitem_array',
#  '_setitem_frame',
#  '_setitem_slice',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_stat_function',
#  '_stat_function_ddof',
#  '_take_with_is_copy',
#  '_to_dict_of_blocks',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'aperture',
#  'append',
#  'apply',
#  'applymap',
#  'asfreq',
#  'asof',
#  'assign',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'auto_focus',
#  'axes',
#  'backfill',
#  'battery_capacity',
#  'battery_type',
#  'between_time',
#  'bfill',
#  'bool',
#  'boxplot',
#  'brand_rank',
#  'clip',
#  'columns',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'display_resolution',
#  'display_type',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'eval',
#  'ewm',
#  'expandable_memory',
#  'expanding',
#  'explode',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'flags',
#  'flash_type',
#  'floordiv',
#  'frames_per_second',
#  'from_dict',
#  'from_records',
#  'front_camera_resolution',
#  'ge',
#  'get',
#  'gpu_rank',
#  'groupby',
#  'gt',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'insert',
#  'internal_memory',
#  'interpolate',
#  'is_liked',
#  'isin',
#  'isna',
#  'isnull',
#  'items',
#  'iteritems',
#  'iterrows',
#  'itertuples',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lookup',
#  'lt',
#  'mad',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'melt',
#  'memory_usage',
#  'merge',
#  'micro_sd_slot',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'ndim',
#  'ne',
#  'nlargest',
#  'no_of_cores',
#  'no_of_reviews_in_gsmarena_in_week',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'os',
#  'pad',
#  'pct_change',
#  'phone_height',
#  'phone_width',
#  'pipe',
#  'pivot',
#  'pivot_table',
#  'plot',
#  'pop',
#  'pow',
#  'price',
#  'primary_camera_resolution',
#  'processor_frequency',
#  'processor_rank',
#  'prod',
#  'product',
#  'quantile',
#  'query',
#  'radd',
#  'ram_memory',
#  'rank',
#  'rdiv',
#  'reindex',
#  'reindex_like',
#  'removable_battery',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'screen_pixel_density',
#  'screen_protection',
#  'screen_size',
#  'select_dtypes',
#  'sem',
#  'set_axis',
#  'set_flags',
#  'set_index',
#  'shape',
#  'shift',
#  'sim_size',
#  'sim_type',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort_index',
#  'sort_values',
#  'squeeze',
#  'stack',
#  'stand_by_time',
#  'std',
#  'style',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'talk_time',
#  'thickness',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_feather',
#  'to_gbq',
#  'to_hdf',
#  'to_html',
#  'to_json',
#  'to_latex',
#  'to_markdown',
#  'to_numpy',
#  'to_parquet',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'to_xml',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'unstack',
#  'update',
#  'usb_type',
#  'value_counts',
#  'values',
#  'var',
#  'version',
#  'video_resolution',
#  'water_proof_rate',
#  'weight',
#  'where',
#  'xs']

# %%
len(df)
# Out:
# 109

# %%
df.shape
# Out:
# (109, 40)

# %%
df.loc[5]
# Out:
# sim_type                                0.0
# aperture                               14.0
# gpu_rank                               55.0
# weight                                179.0
# stand_by_time                         280.0
# processor_frequency                     1.3
# thickness                               7.9
# flash_type                              5.0
# front_camera_resolution                 5.0
# auto_focus                              3.0
# screen_size                             5.5
# frames_per_second                      30.0
# FM                                      3.0
# no_of_reviews_in_gsmarena_in_week       6.0
# os                                      0.0
# phone_height                          150.0
# screen_protection                       5.0
# sim_size                                3.0
# price                                5999.0
# talk_time                              22.0
# video_resolution                      720.0
# display_resolution                      0.0
# removable_battery                       0.0
# display_type                            2.0
# primary_camera_resolution               8.0
# battery_type                            1.0
# ram_memory                              1.0
# internal_memory                         7.0
# brand_rank                              4.0
# no_of_cores                             6.0
# micro_sd_slot                           4.0
# screen_pixel_density                    7.0
# water_proof_rate                        3.0
# phone_width                            71.0
# expandable_memory                      32.0
# version                                 6.0
# usb_type                                3.0
# battery_capacity                     2900.0
# processor_rank                        165.0
# is_liked                                0.0
# Name: 5, dtype: float64

# %%
# we can create a new dataframe containing that exact row
df_short = df[0:10]

# %%
df_short.shape
# Out:
# (10, 40)

# %%
df_short.head()
# Out:
#    sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0         0        12        55   155.0            250                  1.3
# 1         0         1        55   132.0            300                  1.3
# 2         0         9        55   142.0            329                  1.5
# 3         0         8        55   152.0            385                  1.3
# 4         1         1        55   234.0            385                  1.3
#
#    thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 0       10.5           5                     2.00           0  ...
# 1       10.6           5                     0.30           1  ...
# 2        8.5           5                     2.00           3  ...
# 3        8.0           5                     2.00           3  ...
# 4        7.9           5                     1.92           3  ...
#
#    micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# 0              4                     2                 3         67.8
# 1              4                     4                 6         64.0
# 2              4                     9                 6         72.0
# 3              4                     1                 3         75.1
# 4              4                     1                 6         91.0
#
#    expandable_memory  version  usb_type  battery_capacity  processor_rank  \
# 0               64.0        5         3              2000             125
# 1               32.0        5         3              2000             165
# 2               32.0        6         3              2500             164
# 3               32.0        6         3              3000             165
# 4               32.0        6         3              3000             165
#
#    is_liked
# 0         1
# 1         1
# 2         0
# 3         1
# 4         0
#
# [5 rows x 40 columns]

# %%
#for columns
df_thin = df[['stand_by_time', 'expandable_memory', 'price', 'battery_capacity', 'is_liked']]

# %%
df_thin.shape
# Out:
# (109, 5)

# %%
df_thin.head()
# Out:
#    stand_by_time  expandable_memory  price  battery_capacity  is_liked
# 0            250               64.0   3870              2000         1
# 1            300               32.0   4059              2000         1
# 2            329               32.0   4777              2500         0
# 3            385               32.0   5799              3000         1
# 4            385               32.0   5990              3000         0

# %%
df_liked = df_thin[df_thin['is_liked'] == 1]

# %%
df_liked.shape
# Out:
# (92, 5)

# %%
df_thin['price'].mean()
# Out:
# 19373.211009174312

# %%
df_thin['price'].min()
# Out:
# 3870

# %%
df_thin['price'].max()
# Out:
# 64500

# %%
df_thin['price'].describe()
# Out:
# count      109.000000
# mean     19373.211009
# std      14039.197220
# min       3870.000000
# 25%       8999.000000
# 50%      14614.000000
# 75%      24999.000000
# max      64500.000000
# Name: price, dtype: float64

# %%
df_thin.describe()
# Out:
#        stand_by_time  expandable_memory         price  battery_capacity  \
# count      109.00000         109.000000    109.000000        109.000000
# mean       404.66055         104.513761  19373.211009       2841.779817
# std        176.44206         275.799767  14039.197220        655.003963
# min        160.00000           0.000000   3870.000000       1560.000000
# 25%        264.00000           0.000000   8999.000000       2470.000000
# 50%        360.00000          32.000000  14614.000000       2900.000000
# 75%        500.00000         128.000000  24999.000000       3100.000000
# max       1093.00000        2048.000000  64500.000000       5000.000000
#
#          is_liked
# count  109.000000
# mean     0.844037
# std      0.364496
# min      0.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %%
df_thin[df_thin['is_liked'] == 1]['price'].mean()
# Out:
# 19393.239130434784

# %%
df_thin[df_thin['is_liked'] == 0]['price'].mean()
# Out:
# 19264.823529411766

# %%
g = df_thin.groupby(['is_liked'])

# %%
for key, df_key in g:
    print(key)
    print(df_key)
# Out:
# 0
#      stand_by_time  expandable_memory  price  battery_capacity  is_liked
# 2              329               32.0   4777              2500         0
# 4              385               32.0   5990              3000         0
# 5              280               32.0   5999              2900         0
# 11             300              128.0   6990              2600         0
# 22             354              128.0   7999              2400         0
# 38             490               32.0   9999              2100         0
# 53             345               64.0  14300              2950         0
# 60             840                0.0  15689              4100         0
# 74             390              128.0  21999              2800         0
# 77             620              128.0  22999              3100         0
# 78             618                0.0  24499              3600         0
# 80             598                0.0  24999              3000         0
# 83             504              200.0  25500              2600         0
# 90             500                0.0  34999              3760         0
# 91             240                0.0  34999              1624         0
# 95             580              256.0  37766              2840         0
# 108            400                0.0  27999              3000         0
# 1
#      stand_by_time  expandable_memory  price  battery_capacity  is_liked
# 0              250               64.0   3870              2000         1
# 1              300               32.0   4059              2000         1
# 3              385               32.0   5799              3000         1
# 6              230              128.0   5999              1700         1
# 7              182               32.0   6599              2000         1
# ..             ...                ...    ...               ...       ...
# 103            600              256.0  52699              3430         1
# 104            540              256.0  54900              3410         1
# 105            400              200.0  56900              3600         1
# 106            384                0.0  59000              2750         1
# 107            250                0.0  64500              1810         1
#
# [92 rows x 5 columns]

# %%
df_thin.groupby(['is_liked']).mean()
# Out:
#           stand_by_time  expandable_memory         price  battery_capacity
# is_liked
# 0            457.235294          68.235294  19264.823529       2874.941176
# 1            394.945652         111.217391  19393.239130       2835.652174

# %%
df_thin.groupby(['is_liked']).describe()
# Out:
#          stand_by_time                                                       \
#                  count        mean         std    min     25%    50%    75%
# is_liked
# 0                 17.0  457.235294  157.094927  240.0  345.00  400.0  580.0
# 1                 92.0  394.945652  178.876246  160.0  258.25  354.0  482.0
#
#                  expandable_memory              ...     price           \
#              max             count        mean  ...       75%      max
# is_liked                                        ...
# 0          840.0              17.0   68.235294  ...  25500.00  37766.0
# 1         1093.0              92.0  111.217391  ...  24924.75  64500.0
#
#          battery_capacity                                                   \
#                     count         mean         std     min     25%     50%
# is_liked
# 0                    17.0  2874.941176  591.777035  1624.0  2600.0  2900.0
# 1                    92.0  2835.652174  668.850998  1560.0  2457.5  2900.0
#
#
#              75%     max
# is_liked
# 0         3000.0  4100.0
# 1         3100.0  5000.0
#
# [2 rows x 32 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
ax = sns.pairplot(df_thin, diag_kind = 'hist')

# %%
ax = sns.pairplot(df_thin, diag_kind = 'hist', hue='is_liked' )

# %% [markdown]
# # Debugging

# %%
def factorial(x):
    if x == 0 or x == 1:
        return 1
    return x * factorial(x-1)

# %%
factorial(5)
# Out:
# 120

# %%
import random

# %%
def code_to_debugg():
    import pdb; pdb.set_trace() # python package
    for i in range(10):
        x = random.random()
        factorial(x)

# %%
code_to_debugg()
# Out:
# > /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/288901655.py(3)code_to_debugg()
#       1 def code_to_debugg():
#       2     import pdb; pdb.set_trace() # python package
# ----> 3     for i in range(10):
#       4         x = random.random()
#       5         factorial(x)
#
# ipdb> ?
#
# Documented commands (type help <topic>):
# ========================================
# EOF    commands   enable    ll        pp       s                until
# a      condition  exit      longlist  psource  skip_hidden      up
# alias  cont       h         n         q        skip_predicates  w
# args   context    help      next      quit     source           whatis
# b      continue   ignore    p         r        step             where
# break  d          interact  pdef      restart  tbreak
# bt     debug      j         pdoc      return   u
# c      disable    jump      pfile     retval   unalias
# cl     display    l         pinfo     run      undisplay
# clear  down       list      pinfo2    rv       unt
#
# Miscellaneous help topics:
# ==========================
# exec  pdb
#
# ipdb> help c
# c(ont(inue))
#         Continue execution, only stop when a breakpoint is encountered.
# ipdb> l
#       1 def code_to_debugg():
#       2     import pdb; pdb.set_trace() # python package
# ----> 3     for i in range(10):
#       4         x = random.random()
#       5         factorial(x)
#
# ipdb> n
# > /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/288901655.py(4)code_to_debugg()
#       1 def code_to_debugg():
#       2     import pdb; pdb.set_trace() # python package
#       3     for i in range(10):
# ----> 4         x = random.random()
#       5         factorial(x)
#
# ipdb> l
#       1 def code_to_debugg():
#       2     import pdb; pdb.set_trace() # python package
#       3     for i in range(10):
# ----> 4         x = random.random()
#       5         factorial(x)
#
# ipdb> n
# > /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/288901655.py(5)code_to_debugg()
#       1 def code_to_debugg():
#       2     import pdb; pdb.set_trace() # python package
#       3     for i in range(10):
#       4         x = random.random()
# ----> 5         factorial(x)
#
# ipdb> n
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/1305125395.py in <module>
# ----> 1 code_to_debugg()
#
# /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/288901655.py in code_to_debugg()
#       3     for i in range(10):
#       4         x = random.random()
# ----> 5         factorial(x)
#
# /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/2290578483.py in factorial(x)
#       2     if x == 0 or x == 1:
#       3         return 1
# ----> 4     return x * factorial(x-1)
#
# ... last 1 frames repeated, from the frame below ...
#
# /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/2290578483.py in factorial(x)
#       2     if x == 0 or x == 1:
#       3         return 1
# ----> 4     return x * factorial(x-1)
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
code_to_debugg()
# Out:
# > /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/288901655.py(3)code_to_debugg()
#       1 def code_to_debugg():
#       2     import pdb; pdb.set_trace() # python package
# ----> 3     for i in range(10):
#       4         x = random.random()
#       5         factorial(x)
#
# ipdb> n
# > /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/288901655.py(4)code_to_debugg()
#       1 def code_to_debugg():
#       2     import pdb; pdb.set_trace() # python package
#       3     for i in range(10):
# ----> 4         x = random.random()
#       5         factorial(x)
#
# ipdb> n
# > /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/288901655.py(5)code_to_debugg()
#       1 def code_to_debugg():
#       2     import pdb; pdb.set_trace() # python package
#       3     for i in range(10):
#       4         x = random.random()
# ----> 5         factorial(x)
#
# ipdb> ?
#
# Documented commands (type help <topic>):
# ========================================
# EOF    commands   enable    ll        pp       s                until
# a      condition  exit      longlist  psource  skip_hidden      up
# alias  cont       h         n         q        skip_predicates  w
# args   context    help      next      quit     source           whatis
# b      continue   ignore    p         r        step             where
# break  d          interact  pdef      restart  tbreak
# bt     debug      j         pdoc      return   u
# c      disable    jump      pfile     retval   unalias
# cl     display    l         pinfo     run      undisplay
# clear  down       list      pinfo2    rv       unt
#
# Miscellaneous help topics:
# ==========================
# exec  pdb
#
# ipdb> help step
# s(tep)
#         Execute the current line, stop at the first possible occasion
#         (either in a function that is called or in the current
#         function).
# ipdb> s
# --Call--
# > /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/2290578483.py(1)factorial()
# ----> 1 def factorial(x):
#       2     if x == 0 or x == 1:
#       3         return 1
#       4     return x * factorial(x-1)
#
# ipdb> n
# > /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/2290578483.py(2)factorial()
#       1 def factorial(x):
# ----> 2     if x == 0 or x == 1:
#       3         return 1
#       4     return x * factorial(x-1)
#
# ipdb> n
# > /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/2290578483.py(4)factorial()
#       1 def factorial(x):
#       2     if x == 0 or x == 1:
#       3         return 1
# ----> 4     return x * factorial(x-1)
#
# ipdb> print(x)
# 0.03907835138491389
# ipdb> print(x-1)
# -0.9609216486150861
# ipdb> s
# --Call--
# > /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/2290578483.py(1)factorial()
# ----> 1 def factorial(x):
#       2     if x == 0 or x == 1:
#       3         return 1
#       4     return x * factorial(x-1)
#
# ipdb> print(x)
# -0.9609216486150861
# ipdb> quit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/1305125395.py in <module>
# ----> 1 code_to_debugg()
#
# /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/288901655.py in code_to_debugg()
#       3     for i in range(10):
#       4         x = random.random()
# ----> 5         factorial(x)
#
# /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/2290578483.py in factorial(x)
#       2     if x == 0 or x == 1:
#       3         return 1
# ----> 4     return x * factorial(x-1)
#
# /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/2290578483.py in factorial(x)
# ----> 1 def factorial(x):
#       2     if x == 0 or x == 1:
#       3         return 1
#       4     return x * factorial(x-1)
#
# /opt/anaconda3/lib/python3.9/bdb.py in trace_dispatch(self, frame, event, arg)
#      88             return self.dispatch_line(frame)
#      89         if event == 'call':
# ---> 90             return self.dispatch_call(frame, arg)
#      91         if event == 'return':
#      92             return self.dispatch_return(frame, arg)
#
# /opt/anaconda3/lib/python3.9/bdb.py in dispatch_call(self, frame, arg)
#     133             return self.trace_dispatch
#     134         self.user_call(frame, arg)
# --> 135         if self.quitting: raise BdbQuit
#     136         return self.trace_dispatch
#     137
#
# BdbQuit:

# %%
def factorial_debugged(x):
    if(not isinstance(x,int)):
        print("This method only supports integers")
        return -1
    if x == 0 or x == 1:
        return 1
    return x * factorial(x-1)

# %%
def code_to_debugg1():
    import pdb; pdb.set_trace() # python package
    for i in range(10):
        x = random.random()
        factorial_debugged(x)

# %%
code_to_debugg1()
# Out:
# > /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/1962747838.py(3)code_to_debugg1()
#       1 def code_to_debugg1():
#       2     import pdb; pdb.set_trace() # python package
# ----> 3     for i in range(10):
#       4         x = random.random()
#       5         factorial_debugged(x)
#
# ipdb> ?
#
# Documented commands (type help <topic>):
# ========================================
# EOF    commands   enable    ll        pp       s                until
# a      condition  exit      longlist  psource  skip_hidden      up
# alias  cont       h         n         q        skip_predicates  w
# args   context    help      next      quit     source           whatis
# b      continue   ignore    p         r        step             where
# break  d          interact  pdef      restart  tbreak
# bt     debug      j         pdoc      return   u
# c      disable    jump      pfile     retval   unalias
# cl     display    l         pinfo     run      undisplay
# clear  down       list      pinfo2    rv       unt
#
# Miscellaneous help topics:
# ==========================
# exec  pdb
#
# ipdb> c
# This method only supports integers
# This method only supports integers
# This method only supports integers
# This method only supports integers
# This method only supports integers
# This method only supports integers
# This method only supports integers
# This method only supports integers
# This method only supports integers
# This method only supports integers

# %%
def factorial(x):
    if x == 0 or x == 1:
        return 1
    return x * factorial(x-1)

# %%
def code_to_debugg():
#     import pdb; pdb.set_trace() # python package
    for i in range(10):
        x = random.random()
        factorial(x)

# %%
# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %%
code_to_debugg()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/1305125395.py in <module>
# ----> 1 code_to_debugg()
#         global code_to_debugg = <function code_to_debugg at 0x7f94d134ee50>
#
# /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/3046436090.py in code_to_debugg()
#       3     for i in range(10):
#       4         x = random.random()
# ----> 5         factorial(x)
#         global factorial = <function factorial at 0x7f94d12dfc10>
#         x = 0.8034858136382608
#
# /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/2290578483.py in factorial(x=0.8034858136382608)
#       2     if x == 0 or x == 1:
#       3         return 1
# ----> 4     return x * factorial(x-1)
#         x = 0.8034858136382608
#         global factorial = <function factorial at 0x7f94d12dfc10>
#
# ... last 1 frames repeated, from the frame below ...
#
# /var/folders/lh/p8_gmp0j3kd1x16y44x1x82m0000gn/T/ipykernel_1649/2290578483.py in factorial(x=-0.19651418636173923)
#       2     if x == 0 or x == 1:
#       3         return 1
# ----> 4     return x * factorial(x-1)
#         x = -0.19651418636173923
#         global factorial = <function factorial at 0x7f94d12dfc10>
#
# RecursionError: maximum recursion depth exceeded in comparison
